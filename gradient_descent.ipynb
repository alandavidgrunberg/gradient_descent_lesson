# %%
from IPython.display import Image

# %%
Image('slides/1.jpg')

# %%
Image('slides/2.jpg')

# %%
Image('slides/3.jpg')

# %%
Image('slides/4.jpg')

# %%
Image('slides/5.jpg')

# %%
Image('slides/6.jpg')

# %%
Image('slides/7.jpg')

# %%
Image('slides/8.jpg')

# %%
Image('slides/9.jpg')

# %%
Image('slides/10.jpg')

# %%
Image('slides/11.jpg')

# %%
Image('slides/12.jpg')

# %%
Image('slides/13.jpg')

# %%
Image('slides/14.jpg')

# %%
Image('slides/15.jpg')

# %%
Image('slides/16.jpg')

# %%
Image('slides/17.jpg')

# %%
Image('slides/18.jpg')

# %%
Image('slides/19.jpg')

# %%
Image('slides/20.jpg')

# %%
Image('slides/21.jpg')

# %%
Image('slides/22.jpg')

# %%
Image('slides/23.jpg')

# %%
Image('slides/24.jpg')

# %%
Image('slides/25.jpg')

# %%
Image('slides/26.jpg')

# %%
Image('slides/27.jpg')

# %%
Image('slides/28.jpg')

# %%
Image('slides/29.jpg')
